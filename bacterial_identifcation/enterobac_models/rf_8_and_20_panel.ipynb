# %%
import pandas as pd
import numpy as np
# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

from joblib import dump, load
from pathlib import Path

# %%
entero_bac_100_data_path = Path('/Users/thomaslim/microbis/PyBact_1.0.1/enterobac_100_train_data.txt')
df_enterobac_data = pd.read_csv(entero_bac_100_data_path, sep='\t')
df_enterobac_data.rename({'Unnamed: 48': 'Target'}, axis=1, inplace=True)

# %%
DATA_8_PANEL_PATH = '/Users/thomaslim/microbis/bacterial_identifcation_models/enterobac_models/panels/panels_8.txt'
panels_8_dict = {}
with open(DATA_8_PANEL_PATH, 'r') as f:
    for line in f:
        name1, name2 = line.split(',', 1)
        panels_8_dict[name1] = name2.strip()
columns_8 = list(panels_8_dict.values())

# %%
DATA_20_PANEL_PATH = '/Users/thomaslim/microbis/bacterial_identifcation_models/enterobac_models/panels/panels_20.txt'
panels_20_dict = {}
with open(DATA_20_PANEL_PATH, 'r') as f:
    for line in f:
        name1, name2 = line.split(',', 1)
        panels_20_dict[name1] = name2.strip()
columns_20 = list(panels_20_dict.values())

# %%
X_8_panel= df_enterobac_data[columns_8]
y = df_enterobac_data['Target']
X_train, X_test, y_train, y_test = train_test_split(X_8_panel, y, test_size=0.2, random_state=42)

model_8_panel = RandomForestClassifier(n_estimators=100, random_state=42)
model_8_panel.fit(X_train, y_train)
y_pred = model_8_panel.predict(X_test)
y_pred_proba = model_8_panel.predict_proba(X_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.31404109589041096

# %%
# Save X_test and y_test together as the test set
X_test['Target'] = y_test
X_test.to_csv('rf_8_panel_enterobac_100_test_set.csv', index=False)

# %%
y_pred.tolist()
# Out:
# ['C.gillenii',
#  'C.warkmanii',
#  'C.warkmanii',
#  'E.aloacae',
#  'K.ornithinolytica',
#  'K.pneumoniae',
#  'E.cancerogenus',
#  'C.diversus_C.koseri',
#  'S.rubidaea',
#  'L.grimontii',
#  'M.wisconsensis',
#  'P.rustigianni',
#  'Yersinia_ruckeri',
#  'E.cancerogenus',
#  'E.cancerogenus',
#  'B.brennerae',
#  'E.cancerogenus',
#  'C.sedlakii',
#  'E.pyrinus',
#  'S.Gallinarum_Group_I',
#  'Enteric_Group_64',
#  'B.brennerae',
#  'B.brennerae',
#  'M.morganii_biogroup_1',
#  'B.aquatica',
#  'P.vulgeris',
#  'P.fontium',
#  'P.asymbiotica',
#  'M.morganii_biogroup_1',
#  'R.aquatilis',
#  'S.Gallinarum_Group_I',
#  'M.morganii_biogroup_1',
#  'C.diversus_C.koseri',
#  'E.cancerogenus',
#  'Yersinia_ruckeri',
#  'Y.pseudotuberculosis',
#  'B.brennerae',
#  'Yersinia_ruckeri',
#  'S.entomoohila',
#  'B.izardii',
#  'B.brennerae',
#  'S.Group_IV_strains',
#  'C.diversus_C.koseri',
#  'S.rubidaea',
#  'C.warkmanii',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'C.diversus_C.koseri',
#  'E.dissolvens',
#  'S.Choleresuis_Group_I',
#  'K.georgiana',
#  'B.izardii',
#  'Yersinia_ruckeri',
#  'C.warkmanii',
#  'E.nimipressuralis',
#  'Yersinia_ruckeri',
#  'C.rodentium',
#  'E.blattae',
#  'B.brennerae',
#  'E.coli',
#  'P.vulgeris',
#  'T.guamensis',
#  'S.Group_IV_strains',
#  'E.nimipressuralis',
#  'P.myxofaciens',
#  'E.nimipressuralis',
#  'E.cancerogenus',
#  'E.dissolvens',
#  'E.coil_invasive',
#  'E.dissolvens',
#  'E.tarda',
#  'R.aquatilis',
#  'Y.pseudotuberculosis',
#  'E.pyrinus',
#  'S.entomoohila',
#  'C.warkmanii',
#  'P.myxofaciens',
#  'E.tarda',
#  'E.cancerogenus',
#  'Y.pseudotuberculosis',
#  'C.diversus_C.koseri',
#  'E.tarda_biogroup_1',
#  'P.asymbiotica',
#  'S.Choleresuis_Group_I',
#  'E.coil_invasive',
#  'S.rubidaea',
#  'K.pneumoniae',
#  'Y.mollaretii',
#  'M.morganii_biogroup_1',
#  'S.entomoohila',
#  'P.asymbiotica',
#  'C.amalonaticus',
#  'K.ornithinolytica',
#  'B.agrestic',
#  'S.Group_IV_strains',
#  'E.cancerogenus',
#  'Yersinia_ruckeri',
#  'Y.pseudotuberculosis',
#  'C.Group_137',
#  'C.warkmanii',
#  'Yersinia_ruckeri',
#  'E.cancerogenus',
#  'B.brennerae',
#  'S.Gallinarum_Group_I',
#  'E.dissolvens',
#  'S.entomoohila',
#  'E.blattae',
#  'B.brennerae',
#  'P.myxofaciens',
#  'Yersinia_ruckeri',
#  'E.coil_invasive',
#  'E.cancerogenus',
#  'K.georgiana',
#  'C.rodentium',
#  'C.sedlakii',
#  'P.rettgeri',
#  'C.diversus_C.koseri',
#  'S.Gallinarum_Group_I',
#  'K.ornithinolytica',
#  'C.gillenii',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'K.pneumoniae',
#  'P.penneri',
#  'E.cancerogenus',
#  'K.georgiana',
#  'S.entomoohila',
#  'K.georgiana',
#  'Yersinia_ruckeri',
#  'B.izardii',
#  'E.cancerogenus',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'E.dissolvens',
#  'E.coli',
#  'E.coil_invasive',
#  'E.cancerogenus',
#  'E.coli',
#  'M.morganii_biogroup_1',
#  'B.agrestic',
#  'C.sedlakii',
#  'T.guamensis',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'E.cancerogenus',
#  'K.ornithinolytica',
#  'P.myxofaciens',
#  'K.ascorbata',
#  'S.Group_IV_strains',
#  'S.entomoohila',
#  'P.myxofaciens',
#  'R.aquatilis',
#  'K.oxytoca',
#  'C.sedlakii',
#  'Enteric_Group_64',
#  'P.heimbachae',
#  'Yersinia_ruckeri',
#  'S.Group_IV_strains',
#  'E.pyrinus',
#  'E.coli',
#  'C.warkmanii',
#  'S.entomoohila',
#  'P.asymbiotica',
#  'S.Group_IIIb_strains',
#  'Y.pseudotuberculosis',
#  'M.wisconsensis',
#  'Y.intermedia',
#  'P.myxofaciens',
#  'P.heimbachae',
#  'S.Group_IIIb_strains',
#  'S.Group_IV_strains',
#  'B.agrestic',
#  'S.Group_IV_strains',
#  'S.entomoohila',
#  'S.Group_IV_strains',
#  'E.cancerogenus',
#  'E.tarda_biogroup_1',
#  'K.ornithinolytica',
#  'B.agrestic',
#  'C.sedlakii',
#  'B.aquatica',
#  'P.vulgeris',
#  'E.nimipressuralis',
#  'Y.mollaretii',
#  'C.rodentium',
#  'C.diversus_C.koseri',
#  'B.agrestic',
#  'E.cancerogenus',
#  'E.cancerogenus',
#  'P.alcalifaciens',
#  'S.rubidaea',
#  'M.morganii_biogroup_1',
#  'E.tarda',
#  'S.rubidaea',
#  'B.agrestic',
#  'P.myxofaciens',
#  'E.cancerogenus',
#  'S.fergusonii',
#  'C.warkmanii',
#  'E.coil_invasive',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'S.pullorum_Group_I',
#  'E.tarda_biogroup_1',
#  'C.gillenii',
#  'Yersinia_ruckeri',
#  'E.coli',
#  'Yersinia_ruckeri',
#  'E.coil_invasive',
#  'B.agrestic',
#  'E.nimipressuralis',
#  'P.asymbiotica',
#  'E.pyrinus',
#  'S.Group_IV_strains',
#  'S.Group_IIIb_strains',
#  'S.Gallinarum_Group_I',
#  'Yersinia_ruckeri',
#  'C.warkmanii',
#  'M.wisconsensis',
#  'Yersinia_ruckeri',
#  'T.guamensis',
#  'L.grimontii',
#  'Yersinia_ruckeri',
#  'K.ornithinolytica',
#  'P.asymbiotica',
#  'P.heimbachae',
#  'C.rodentium',
#  'S.Gallinarum_Group_I',
#  'S.Gallinarum_Group_I',
#  'B.izardii',
#  'S.Group_IV_strains',
#  'Y.pseudotuberculosis',
#  'P.stuartii',
#  'E.coli',
#  'Enteric_Group_64',
#  'B.agrestic',
#  'C.amalonaticus',
#  'E.coli',
#  'B.agrestic',
#  'E.coil_invasive',
#  'Yersinia_ruckeri',
#  'E.cancerogenus',
#  'E.coil_invasive',
#  'S.Group_IV_strains',
#  'B.agrestic',
#  'E.coli',
#  'Y.pseudotuberculosis',
#  'Y.pseudotuberculosis',
#  'P.alcalifaciens',
#  'Y.mollaretii',
#  'K.georgiana',
#  'C.amalonaticus',
#  'B.izardii',
#  'C.Group_137',
#  'S.fergusonii',
#  'S.Gallinarum_Group_I',
#  'P.heimbachae',
#  'Yersinia_ruckeri',
#  'B.izardii',
#  'S.Group_IV_strains',
#  'Y.intermedia',
#  'C.murliniae',
#  'L.grimontii',
#  'S.Gallinarum_Group_I',
#  'K.ascorbata',
#  'C.amalonaticus',
#  'K.georgiana',
#  'E.coil_invasive',
#  'S.Gallinarum_Group_I',
#  'C.warkmanii',
#  'L.adecarboxylata',
#  'B.agrestic',
#  'S.entomoohila',
#  'C.diversus_C.koseri',
#  'Yersinia_ruckeri',
#  'Y.mollaretii',
#  'Enteric_Group_64',
#  'C.sedlakii',
#  'C.warkmanii',
#  'C.rodentium',
#  'E.coil_invasive',
#  'Yersinia_ruckeri',
#  'B.izardii',
#  'P.luminescens',
#  'B.agrestic',
#  'S.rubidaea',
#  'Y.intermedia',
#  'Yersinia_ruckeri',
#  'S.entomoohila',
#  'P.heimbachae',
#  'E.cancerogenus',
#  'P.alcalifaciens',
#  'S.Group_IV_strains',
#  'P.myxofaciens',
#  'C.sedlakii',
#  'C.rodentium',
#  'S.fergusonii',
#  'B.brennerae',
#  'Y.pseudotuberculosis',
#  'C.warkmanii',
#  'Y.mollaretii',
#  'S.fergusonii',
#  'Yersinia_ruckeri',
#  'E.dissolvens',
#  'P.vulgeris',
#  'K.georgiana',
#  'S.entomoohila',
#  'C.murliniae',
#  'S.Gallinarum_Group_I',
#  'S.Choleresuis_Group_I',
#  'Yersinia_ruckeri',
#  'P.heimbachae',
#  'Yersinia_ruckeri',
#  'C.sedlakii',
#  'K.terrigena',
#  'B.brennerae',
#  'E.dissolvens',
#  'E.coil_invasive',
#  'K.pneumoniae',
#  'B.izardii',
#  'Y.pseudotuberculosis',
#  'E.cancerogenus',
#  'S.Gallinarum_Group_I',
#  'T.guamensis',
#  'C.warkmanii',
#  'E.coil_invasive',
#  'P.myxofaciens',
#  'P.fontium',
#  'S.Gallinarum_Group_I',
#  'C.diversus_C.koseri',
#  'S.rubidaea',
#  'B.brennerae',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'Y.pseudotuberculosis',
#  'C.sedlakii',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'B.agrestic',
#  'S.fergusonii',
#  'K.ornithinolytica',
#  'C.warkmanii',
#  'E.cancerogenus',
#  'Y.mollaretii',
#  'C.rodentium',
#  'Y.pseudotuberculosis',
#  'L.grimontii',
#  'B.izardii',
#  'S.rubidaea',
#  'E.cancerogenus',
#  'C.youngae',
#  'S.fergusonii',
#  'S.rubidaea',
#  'Enteric_Group_64',
#  'E.nimipressuralis',
#  'B.agrestic',
#  'S.pullorum_Group_I',
#  'S.fergusonii',
#  'P.stuartii',
#  'Enteric_Group_64',
#  'B.agrestic',
#  'P.myxofaciens',
#  'P.stuartii',
#  'E.coil_invasive',
#  'E.cancerogenus',
#  'K.pneumoniae',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'C.murliniae',
#  'S.Group_IV_strains',
#  'B.brennerae',
#  'E.coli',
#  'P.myxofaciens',
#  'Enteric_Group_64',
#  'C.warkmanii',
#  'Yersinia_ruckeri',
#  'E.tarda_biogroup_1',
#  'B.brennerae',
#  'E.cancerogenus',
#  'B.agrestic',
#  'E.cancerogenus',
#  'P.alcalifaciens',
#  'K.pneumoniae',
#  'E.blattae',
#  'P.fontium',
#  'B.brennerae',
#  'E.coli',
#  'E.tarda_biogroup_1',
#  'Yersinia_ruckeri',
#  'Y.intermedia',
#  'E.coil_invasive',
#  'S.Group_IV_strains',
#  'C.diversus_C.koseri',
#  'B.agrestic',
#  'M.wisconsensis',
#  'E.blattae',
#  'E.pyrinus',
#  'Yersinia_ruckeri',
#  'L.adecarboxylata',
#  'C.rodentium',
#  'E.tarda_biogroup_1',
#  'M.wisconsensis',
#  'B.brennerae',
#  'Y.intermedia',
#  'E.coil_invasive',
#  'Yersinia_ruckeri',
#  'Y.pseudotuberculosis',
#  'E.pyrinus',
#  'B.izardii',
#  'B.agrestic',
#  'S.Group_IIIb_strains',
#  'B.agrestic',
#  'C.diversus_C.koseri',
#  'S.Group_IV_strains',
#  'Y.pseudotuberculosis',
#  'P.vulgeris',
#  'C.murliniae',
#  'S.Group_IV_strains',
#  'B.brennerae',
#  'S.Group_IV_strains',
#  'C.murliniae',
#  'P.heimbachae',
#  'P.shigelloides',
#  'E.blattae',
#  'M.wisconsensis',
#  'Y.pseudotuberculosis',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'S.Group_IV_strains',
#  'E.tarda_biogroup_1',
#  'E.pyrinus',
#  'B.agrestic',
#  'B.brennerae',
#  'M.morganii_biogroup_1',
#  'B.brennerae',
#  'Yersinia_ruckeri',
#  'B.brennerae',
#  'L.grimontii',
#  'S.entomoohila',
#  'B.agrestic',
#  'E.tarda_biogroup_1',
#  'Yersinia_ruckeri',
#  'K.ascorbata',
#  'P.myxofaciens',
#  'S.marcescens_biogroup_1',
#  'K.georgiana',
#  'E.blattae',
#  'S.rubidaea',
#  'C.diversus_C.koseri',
#  'S.pullorum_Group_I',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'S.fergusonii',
#  'B.agrestic',
#  'P.alcalifaciens',
#  'C.rodentium',
#  'P.heimbachae',
#  'K.georgiana',
#  'Yersinia_ruckeri',
#  'C.youngae',
#  'S.Group_IV_strains',
#  'E.cancerogenus',
#  'C.diversus_C.koseri',
#  'P.heimbachae',
#  'E.blattae',
#  'C.sedlakii',
#  'P.myxofaciens',
#  'P.asymbiotica',
#  'K.ascorbata',
#  'C.sedlakii',
#  'E.tarda',
#  'E.coil_invasive',
#  'C.youngae',
#  'Yersinia_ruckeri',
#  'R.aquatilis',
#  'E.cancerogenus',
#  'B.brennerae',
#  'S.Choleresuis_Group_I',
#  'S.fergusonii',
#  'Y.mollaretii',
#  'B.aquatica',
#  'B.brennerae',
#  'C.Group_137',
#  'E.cancerogenus',
#  'P.shigelloides',
#  'Yersinia_ruckeri',
#  'B.brennerae',
#  'E.tarda_biogroup_1',
#  'B.agrestic',
#  'B.brennerae',
#  'C.rodentium',
#  'Yersinia_ruckeri',
#  'E.blattae',
#  'B.brennerae',
#  'K.terrigena',
#  'C.warkmanii',
#  'P.alcalifaciens',
#  'K.georgiana',
#  'S.Group_IV_strains',
#  'P.rettgeri',
#  'C.warkmanii',
#  'Enteric_Group_64',
#  'P.vulgeris',
#  'C.rodentium',
#  'E.nimipressuralis',
#  'K.ascorbata',
#  'P.penneri',
#  'E.cancerogenus',
#  'B.brennerae',
#  'P.alcalifaciens',
#  'C.sedlakii',
#  'Y.pseudotuberculosis',
#  'B.agrestic',
#  'P.rettgeri',
#  'S.entomoohila',
#  'P.rettgeri',
#  'Yersinia_ruckeri',
#  'B.izardii',
#  'C.diversus_C.koseri',
#  'B.brennerae',
#  'S.rubidaea',
#  'K.oxytoca',
#  'C.sedlakii',
#  'P.asymbiotica',
#  'K.ascorbata',
#  'S.Gallinarum_Group_I',
#  'E.aloacae',
#  'E.cancerogenus',
#  'E.cancerogenus',
#  'K.ascorbata',
#  'E.cancerogenus',
#  'P.myxofaciens',
#  'E.cancerogenus',
#  'C.rodentium',
#  'S.marcescens_biogroup_1',
#  'C.sedlakii',
#  'S.Group_IV_strains',
#  'S.Group_IV_strains',
#  'L.adecarboxylata',
#  'B.brennerae',
#  'E.cancerogenus',
#  'C.freundii',
#  'E.cancerogenus',
#  'B.brennerae',
#  'S.Choleresuis_Group_I',
#  'E.pyrinus',
#  'Yersinia_ruckeri',
#  'Y.mollaretii',
#  'E.aloacae',
#  'C.diversus_C.koseri',
#  'S.rubidaea',
#  'B.agrestic',
#  'L.adecarboxylata',
#  'P.myxofaciens',
#  'S.Group_IIIb_strains',
#  'S.fergusonii',
#  'S.rubidaea',
#  'C.murliniae',
#  'C.amalonaticus',
#  'S.entomoohila',
#  'E.coli',
#  'E.aloacae',
#  'Y.pseudotuberculosis',
#  'E.cancerogenus',
#  'S.fergusonii',
#  'B.brennerae',
#  'B.brennerae',
#  'B.agrestic',
#  'P.shigelloides',
#  'S.Gallinarum_Group_I',
#  'S.entomoohila',
#  'E.nimipressuralis',
#  'C.warkmanii',
#  'P.stuartii',
#  'Yersinia_ruckeri',
#  'P.asymbiotica',
#  'E.cancerogenus',
#  'C.Group_137',
#  'B.izardii',
#  'E.cancerogenus',
#  'S.entomoohila',
#  'B.brennerae',
#  'S.fergusonii',
#  'E.cancerogenus',
#  'C.rodentium',
#  'B.agrestic',
#  'C.sedlakii',
#  'P.heimbachae',
#  'Yersinia_ruckeri',
#  'E.dissolvens',
#  'L.adecarboxylata',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'P.rettgeri',
#  'C.sedlakii',
#  'S.Gallinarum_Group_I',
#  'S.Choleresuis_Group_I',
#  'Yersinia_ruckeri',
#  'C.diversus_C.koseri',
#  'K.terrigena',
#  'B.brennerae',
#  'E.aloacae',
#  'S.Group_IV_strains',
#  'B.brennerae',
#  'C.warkmanii',
#  'P.stuartii',
#  'B.brennerae',
#  'S.Group_IV_strains',
#  'B.agrestic',
#  'Y.intermedia',
#  'K.ornithinolytica',
#  'Yersinia_ruckeri',
#  'P.fontium',
#  'L.grimontii',
#  'B.izardii',
#  'B.brennerae',
#  'L.adecarboxylata',
#  'B.brennerae',
#  'P.alcalifaciens',
#  'Enteric_Group_64',
#  'C.youngae',
#  'E.coil_invasive',
#  'K.ornithinolytica',
#  'K.ascorbata',
#  'E.cancerogenus',
#  'B.agrestic',
#  'B.brennerae',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'C.Group_137',
#  'S.Typhi_Group_I',
#  'E.coli',
#  'Yersinia_ruckeri',
#  'P.mirabilis',
#  'S.Gallinarum_Group_I',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'S.rubidaea',
#  'P.rustigianni',
#  'S.Group_IIIb_strains',
#  'L.adecarboxylata',
#  'Yersinia_ruckeri',
#  'K.ascorbata',
#  'P.heimbachae',
#  'C.Group_137',
#  'E.cancerogenus',
#  'S.Typhi_Group_I',
#  'Y.pseudotuberculosis',
#  'B.brennerae',
#  'S.Group_IIIb_strains',
#  'S.entomoohila',
#  'Y.pseudotuberculosis',
#  'L.grimontii',
#  'Y.mollaretii',
#  'Y.pseudotuberculosis',
#  'K.ornithinolytica',
#  'P.rettgeri',
#  'K.ornithinolytica',
#  'Yersinia_ruckeri',
#  'S.Group_IV_strains',
#  'E.cancerogenus',
#  'S.fergusonii',
#  'E.cancerogenus',
#  'P.rustigianni',
#  'K.terrigena',
#  'P.mirabilis',
#  'C.rodentium',
#  'B.agrestic',
#  'C.rodentium',
#  'S.Typhi_Group_I',
#  'P.myxofaciens',
#  'E.cancerogenus',
#  'S.entomoohila',
#  'E.cancerogenus',
#  'B.brennerae',
#  'C.Group_137',
#  'E.dissolvens',
#  'S.Group_IV_strains',
#  'Y.pseudotuberculosis',
#  'S.fergusonii',
#  'P.stuartii',
#  'E.cancerogenus',
#  'C.warkmanii',
#  'S.Group_IV_strains',
#  'R.aquatilis',
#  'Y.pseudotuberculosis',
#  'P.heimbachae',
#  'E.dissolvens',
#  'S.fergusonii',
#  'S.Gallinarum_Group_I',
#  'Y.intermedia',
#  'R.aquatilis',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'M.wisconsensis',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'S.Choleresuis_Group_I',
#  'C.warkmanii',
#  'E.cancerogenus',
#  'E.coil_invasive',
#  'S.Choleresuis_Group_I',
#  'S.rubidaea',
#  'Y.pseudotuberculosis',
#  'E.tarda_biogroup_1',
#  'B.agrestic',
#  'P.shigelloides',
#  'E.nimipressuralis',
#  'R.aquatilis',
#  'C.rodentium',
#  'S.marcescens_biogroup_1',
#  'C.sedlakii',
#  'Yersinia_ruckeri',
#  'P.heimbachae',
#  'S.entomoohila',
#  'C.sedlakii',
#  'P.shigelloides',
#  'E.nimipressuralis',
#  'P.luminescens',
#  'S.Group_IV_strains',
#  'P.shigelloides',
#  'S.Group_IIIb_strains',
#  'C.Group_137',
#  'L.grimontii',
#  'R.aquatilis',
#  'B.brennerae',
#  'S.entomoohila',
#  'E.tarda_biogroup_1',
#  'P.luminescens',
#  'P.rettgeri',
#  'P.myxofaciens',
#  'L.grimontii',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'C.warkmanii',
#  'C.youngae',
#  'K.ascorbata',
#  'S.Gallinarum_Group_I',
#  'C.diversus_C.koseri',
#  'S.Group_IV_strains',
#  'S.Choleresuis_Group_I',
#  'B.brennerae',
#  'E.nimipressuralis',
#  'P.asymbiotica',
#  'K.pneumoniae',
#  'S.Group_IV_strains',
#  'K.ascorbata',
#  'C.rodentium',
#  'Yersinia_ruckeri',
#  'S.Typhi_Group_I',
#  'K.pneumoniae',
#  'S.Gallinarum_Group_I',
#  'S.Group_IV_strains',
#  'K.ornithinolytica',
#  'S.entomoohila',
#  'E.aloacae',
#  'B.agrestic',
#  'B.aquatica',
#  'S.entomoohila',
#  'S.fergusonii',
#  'S.Group_IV_strains',
#  'B.brennerae',
#  'L.grimontii',
#  'P.stuartii',
#  'S.Group_IV_strains',
#  'K.terrigena',
#  'Yersinia_ruckeri',
#  'S.rubidaea',
#  'B.izardii',
#  'P.heimbachae',
#  'K.oxytoca',
#  'Yersinia_ruckeri',
#  'P.myxofaciens',
#  'P.fontium',
#  'M.morganii_biogroup_1',
#  'B.brennerae',
#  'L.grimontii',
#  'Yersinia_ruckeri',
#  'C.sedlakii',
#  'E.cancerogenus',
#  'S.Group_IV_strains',
#  'S.rubidaea',
#  'K.ornithinolytica',
#  'S.Typhi_Group_I',
#  'C.murliniae',
#  'P.shigelloides',
#  'E.coli',
#  'P.myxofaciens',
#  'Yersinia_ruckeri',
#  'R.aquatilis',
#  'E.coli',
#  'E.aloacae',
#  'S.Gallinarum_Group_I',
#  'B.agrestic',
#  'C.sedlakii',
#  'L.grimontii',
#  'E.tarda',
#  'B.brennerae',
#  'C.sedlakii',
#  'C.murliniae',
#  'B.agrestic',
#  'E.hormaechei',
#  'B.brennerae',
#  'E.blattae',
#  'B.agrestic',
#  'K.pneumoniae',
#  'S.entomoohila',
#  'C.gillenii',
#  'S.entomoohila',
#  'S.Choleresuis_Group_I',
#  'S.entomoohila',
#  'S.Group_IV_strains',
#  'S.Group_IIIb_strains',
#  'S.Group_IV_strains',
#  'B.agrestic',
#  'E.coli',
#  'E.coil_invasive',
#  'E.coli',
#  'S.entomoohila',
#  'C.murliniae',
#  'Yersinia_ruckeri',
#  'E.cancerogenus',
#  'Y.mollaretii',
#  'E.tarda_biogroup_1',
#  'Enteric_Group_64',
#  'P.heimbachae',
#  'M.wisconsensis',
#  'E.tarda',
#  'Yersinia_ruckeri',
#  'C.warkmanii',
#  'C.gillenii',
#  'P.mirabilis',
#  'K.ascorbata',
#  'B.brennerae',
#  'S.fergusonii',
#  'S.fergusonii',
#  'S.rubidaea',
#  'E.nimipressuralis',
#  'E.cancerogenus',
#  'S.Choleresuis_Group_I',
#  'S.fergusonii',
#  'E.coli',
#  'E.cancerogenus',
#  'E.cancerogenus',
#  'C.diversus_C.koseri',
#  'P.alcalifaciens',
#  'Yersinia_ruckeri',
#  'S.fergusonii',
#  'E.coil_invasive',
#  'B.agrestic',
#  'B.agrestic',
#  'P.myxofaciens',
#  'E.blattae',
#  'E.tarda_biogroup_1',
#  'Yersinia_ruckeri',
#  'S.rubidaea',
#  'K.terrigena',
#  'B.agrestic',
#  'P.shigelloides',
#  'C.diversus_C.koseri',
#  'E.nimipressuralis',
#  'B.agrestic',
#  'C.Group_137',
#  'M.wisconsensis',
#  'K.ornithinolytica',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'E.nimipressuralis',
#  'P.rettgeri',
#  'B.izardii',
#  'P.asymbiotica',
#  'Yersinia_ruckeri',
#  'K.ornithinolytica',
#  'S.fergusonii',
#  'P.vulgeris',
#  'Yersinia_ruckeri',
#  'E.coli',
#  'C.murliniae',
#  'E.nimipressuralis',
#  'K.ascorbata',
#  'B.agrestic',
#  'K.pneumoniae',
#  'E.tarda_biogroup_1',
#  'C.Group_137',
#  'C.rodentium',
#  'K.ascorbata',
#  'S.Gallinarum_Group_I',
#  'C.murliniae',
#  'C.rodentium',
#  'E.tarda_biogroup_1',
#  'C.sedlakii',
#  'P.asymbiotica',
#  'P.rettgeri',
#  'S.marcescens_biogroup_1',
#  'P.fontium',
#  'P.shigelloides',
#  'B.agrestic',
#  'E.pyrinus',
#  'S.Gallinarum_Group_I',
#  'M.morganii_biogroup_1',
#  'P.mirabilis',
#  'Yersinia_ruckeri',
#  'K.ornithinolytica',
#  'Y.pseudotuberculosis',
#  'C.warkmanii',
#  'L.adecarboxylata',
#  'E.aloacae',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'E.cancerogenus',
#  'S.Group_IV_strains',
#  'B.agrestic',
#  'Y.pseudotuberculosis',
#  'B.agrestic',
#  'E.cancerogenus',
#  'Yersinia_ruckeri',
#  'B.agrestic',
#  'C.rodentium',
#  'Yersinia_ruckeri',
#  'E.dissolvens',
#  'P.shigelloides',
#  'C.gillenii',
#  'S.fergusonii',
#  'S.marcescens_biogroup_1',
#  'E.aloacae',
#  'E.cancerogenus',
#  'C.warkmanii',
#  'B.brennerae',
#  'P.stuartii',
#  'L.adecarboxylata',
#  'C.diversus_C.koseri',
#  'S.Group_IV_strains',
#  'S.Gallinarum_Group_I',
#  'S.fergusonii',
#  'C.amalonaticus',
#  'S.fergusonii',
#  'P.fontium',
#  'B.izardii',
#  'Yersinia_ruckeri',
#  'Y.pseudotuberculosis',
#  'B.agrestic',
#  'P.stuartii',
#  'E.cancerogenus',
#  'L.adecarboxylata',
#  'E.cancerogenus',
#  'S.Gallinarum_Group_I',
#  'K.oxytoca',
#  'Yersinia_ruckeri',
#  'S.Group_IV_strains',
#  'Yersinia_ruckeri',
#  'P.myxofaciens',
#  'Yersinia_ruckeri',
#  'Yersinia_ruckeri',
#  'C.sedlakii',
#  'P.myxofaciens',
#  'S.rubidaea',
#  'E.coil_invasive',
#  'E.nimipressuralis',
#  'E.coil_invasive',
#  'S.pullorum_Group_I',
#  'Y.mollaretii',
#  'B.brennerae',
#  'E.coil_invasive',
#  'S.pullorum_Group_I',
#  'K.ornithinolytica',
#  'S.entomoohila',
#  'C.rodentium',
#  'B.agrestic',
#  'S.marcescens_biogroup_1',
#  'B.agrestic',
#  'B.agrestic',
#  'B.agrestic',
#  'E.cancerogenus',
#  'L.grimontii',
#  'E.dissolvens',
#  'C.murliniae',
#  'M.wisconsensis',
#  'S.entomoohila',
#  'S.entomoohila',
#  'S.Gallinarum_Group_I',
#  'S.marcescens_biogroup_1',
#  'B.agrestic',
#  'S.entomoohila',
#  'B.agrestic',
#  'E.tarda',
#  'B.agrestic',
#  'P.heimbachae',
#  'K.ascorbata',
#  'M.wisconsensis',
#  'B.agrestic',
#  'Yersinia_ruckeri',
#  'S.rubidaea',
#  'S.fergusonii',
#  'B.agrestic',
#  'Y.intermedia',
#  'B.agrestic',
#  ...]

# %%
X_test
# Out:
#       Urea_hydrolysis  Lactose_fermentation  D-Glucose_acid  Citrate  \
# 169                 0                     1               1        0
# 9354                1                     0               1        1
# 3013                1                     0               1        1
# 1475                1                     1               1        1
# 7420                1                     1               1        1
# ...               ...                   ...             ...      ...
# 1369                0                     0               1        1
# 740                 0                     0               1        0
# 3461                1                     1               1        0
# 5183                1                     0               1        1
# 1188                0                     1               1        1
#
#       Motility  Indole_production  Hydrogen_Sulfide_TSI  D-Glucose_Gas
# 169          0                  0                     1              1
# 9354         1                  0                     1              1
# 3013         1                  0                     1              1
# 1475         1                  0                     0              1
# 7420         0                  1                     0              1
# ...        ...                ...                   ...            ...
# 1369         1                  0                     0              1
# 740          1                  0                     0              1
# 3461         1                  1                     0              0
# 5183         0                  0                     0              1
# 1188         1                  0                     0              1
#
# [2920 rows x 8 columns]

# %%
model_8_panel.predict
# Out:
# {}

# %%
y_pred[0]
# Out:
# 'C.gillenii'

# %%
probability_assignments = []
for probs in y_pred_proba:
    sorted_dict = dict(sorted(zip(model_8_panel.classes_, list(probs)), key=lambda item: item[1], reverse=True))
    probability_assignments.append(sorted_dict)
df_results = pd.DataFrame({
    'true': y_test,
    'predicted': y_pred,
    'probability': probability_assignments
})

# %%
df_results['predicted']
# Out:
# 169            C.gillenii
# 9354          C.warkmanii
# 3013          C.warkmanii
# 1475            E.aloacae
# 7420    K.ornithinolytica
#               ...
# 1369       E.cancerogenus
# 740           B.brennerae
# 3461          C.Group_137
# 5183         E.dissolvens
# 1188           B.agrestic
# Name: predicted, Length: 2920, dtype: object

# %%
# Save the model
dump(model_8_panel, 'rf_8_panel_enterobac_100.pkl')
# Load the model (for future use)
rf_model_loaded = load('rf_8_panel_enterobac_100.pkl')

# %%
rf_model_loaded.predict(X_test)
# Out:
# array(['C.gillenii', 'C.warkmanii', 'C.warkmanii', ..., 'C.Group_137',
#        'E.dissolvens', 'B.agrestic'], dtype=object)

# %%
print(df_results[df_results['true'] != df_results['predicted']].iloc[2])
df_results[df_results['true'] != df_results['predicted']].iloc[2].probability
# Out:
# true                                                  C.freundii
# predicted                                              E.aloacae
# probability    {'E.aloacae': 0.3508532857320039, 'E.gergoviae...
# Name: 1475, dtype: object
# {'E.aloacae': 0.3508532857320039,
#  'E.gergoviae': 0.27121067672838584,
#  'A.dalhousiensis': 0.10949588636023057,
#  'C.freundii': 0.06585199181369887,
#  'C.youngae': 0.057301970404054554,
#  'C.murliniae': 0.04973692030024635,
#  'Serratia_fonticola': 0.04683246009869316,
#  'E.hormaechei': 0.016386892635965312,
#  'E.aerogenes': 0.015106204021126937,
#  'S.rubidaea': 0.009437873626837805,
#  'S.marcescens': 0.007785838278756599,
#  'B.agrestic': 0.0,
#  'B.aquatica': 0.0,
#  'B.brennerae': 0.0,
#  'B.ferragutiae': 0.0,
#  'B.gaviniae': 0.0,
#  'B.izardii': 0.0,
#  'B.noackiae': 0.0,
#  'B.warmboldiae': 0.0,
#  'C.Group_137': 0.0,
#  'C.amalonaticus': 0.0,
#  'C.davisae': 0.0,
#  'C.diversus_C.koseri': 0.0,
#  'C.farmeri': 0.0,
#  'C.gillenii': 0.0,
#  'C.lapagei': 0.0,
#  'C.neteri': 0.0,
#  'C.rodentium': 0.0,
#  'C.sedlakii': 0.0,
#  'C.species_3': 0.0,
#  'C.species_5': 0.0,
#  'C.warkmanii': 0.0,
#  'E.agglomerans_complex': 0.0,
#  'E.americana': 0.0,
#  'E.amnigenus_biogroup_1': 0.0,
#  'E.amnigenus_biogroup_2': 0.0,
#  'E.asburiae': 0.0,
#  'E.blattae': 0.0,
#  'E.cancerogenus': 0.0,
#  'E.coil_invasive': 0.0,
#  'E.coli': 0.0,
#  'E.dissolvens': 0.0,
#  'E.hoshinae': 0.0,
#  'E.ictaluri': 0.0,
#  'E.nimipressuralis': 0.0,
#  'E.pyrinus': 0.0,
#  'E.tarda': 0.0,
#  'E.tarda_biogroup_1': 0.0,
#  'E.taylorae_E.cancerogenus': 0.0,
#  'E.vulneris': 0.0,
#  'Enteric_Group_59': 0.0,
#  'Enteric_Group_60': 0.0,
#  'Enteric_Group_63': 0.0,
#  'Enteric_Group_64': 0.0,
#  'Enteric_Group_68': 0.0,
#  'Enteric_Group_69': 0.0,
#  'Esakazakii': 0.0,
#  'Group_VI_strains': 0.0,
#  'H.alvei': 0.0,
#  'H.alvei_biogroup_1': 0.0,
#  'K.ascorbata': 0.0,
#  'K.cryocrescens': 0.0,
#  'K.georgiana': 0.0,
#  'K.intermedia': 0.0,
#  'K.ornithinolytica': 0.0,
#  'K.oxytoca': 0.0,
#  'K.ozaenae': 0.0,
#  'K.plantocila': 0.0,
#  'K.pneumoniae': 0.0,
#  'K.rhinoscleromatis': 0.0,
#  'K.terrigena': 0.0,
#  'L.adecarboxylata': 0.0,
#  'L.grimontii': 0.0,
#  'L.richardii': 0.0,
#  'M.morganii_biogroup_1': 0.0,
#  'M.morganii_subsp.morganii': 0.0,
#  'M.morganii_subsp.sibonii': 0.0,
#  'M.wisconsensis': 0.0,
#  'O.proteus_biogroup_2': 0.0,
#  'P.alcalifaciens': 0.0,
#  'P.asymbiotica': 0.0,
#  'P.dispersa': 0.0,
#  'P.fontium': 0.0,
#  'P.heimbachae': 0.0,
#  'P.luminescens': 0.0,
#  'P.mirabilis': 0.0,
#  'P.myxofaciens': 0.0,
#  'P.penneri': 0.0,
#  'P.rettgeri': 0.0,
#  'P.rustigianni': 0.0,
#  'P.shigelloides': 0.0,
#  'P.stuartii': 0.0,
#  'P.vulgeris': 0.0,
#  'R.aquatilis': 0.0,
#  'S.Choleresuis_Group_I': 0.0,
#  'S.Gallinarum_Group_I': 0.0,
#  'S.Group_IIIa_strains': 0.0,
#  'S.Group_IIIb_strains': 0.0,
#  'S.Group_II_strains': 0.0,
#  'S.Group_IV_strains': 0.0,
#  'S.Paratyphi_A_Group_I': 0.0,
#  'S.Typhi_Group_I': 0.0,
#  'S.bongeri_Group_V': 0.0,
#  'S.boydii_serogroup_C': 0.0,
#  'S.dysenteriae_serogroup_A': 0.0,
#  'S.enterica_Group_I': 0.0,
#  'S.entomoohila': 0.0,
#  'S.fergusonii': 0.0,
#  'S.ficaria': 0.0,
#  'S.flexneri_serogroup_B': 0.0,
#  'S.hermannii': 0.0,
#  'S.liquefaciens_complex': 0.0,
#  'S.marcescens_biogroup_1': 0.0,
#  'S.odorifera_biogroup_1': 0.0,
#  'S.odorifera_biogroup_2': 0.0,
#  'S.plymuthica': 0.0,
#  'S.pullorum_Group_I': 0.0,
#  'S.sonni_serogroup_D': 0.0,
#  'T.guamensis': 0.0,
#  'T.ptyseos': 0.0,
#  'X.nematophilus': 0.0,
#  'Y.aldovae': 0.0,
#  'Y.bercovieri': 0.0,
#  'Y.enterocolitica': 0.0,
#  'Y.frederiksenii': 0.0,
#  'Y.intermedia': 0.0,
#  'Y.kristensenii': 0.0,
#  'Y.mollaretii': 0.0,
#  'Y.pestis': 0.0,
#  'Y.pseudotuberculosis': 0.0,
#  'Y.regensvurgei_K.trabulsis': 0.0,
#  'Y.rohdei': 0.0,
#  'Yersinia_ruckeri': 0.0}

# %% [markdown]
# ### 20 Panel

# %%
X_20_panel= df_enterobac_data[list(set(columns_20).intersection(df_enterobac_data.columns))]
y = df_enterobac_data['Target']
X_train, X_test, y_train, y_test = train_test_split(X_20_panel, y, test_size=0.2, random_state=42)

model_20_panel = RandomForestClassifier(n_estimators=100, random_state=42)
model_20_panel.fit(X_train, y_train)
y_pred = model_20_panel.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7945205479452054

# %%
# Save X_test and y_test together as the test set
X_test['Target'] = y_test
X_test.to_csv('rf_20_panel_enterobac_100_test_set.csv', index=False)

# %%
X_test
# Out:
#       Indole_production  myo-Inositol_fermentation  Gelatin_hydrolysis_22_c  \
# 169                   0                          0                        0
# 9354                  0                          0                        0
# 3013                  0                          0                        0
# 1475                  0                          0                        0
# 7420                  1                          1                        0
# ...                 ...                        ...                      ...
# 1369                  0                          0                        0
# 740                   0                          0                        0
# 3461                  1                          0                        0
# 5183                  0                          0                        0
# 1188                  0                          0                        0
#
#       D-Sorbitol_fermentation  Arginine_dihydrolase  L-Rhamnose_fermentation  \
# 169                         0                     0                        1
# 9354                        0                     0                        0
# 3013                        1                     1                        1
# 1475                        1                     1                        1
# 7420                        1                     0                        1
# ...                       ...                   ...                      ...
# 1369                        1                     0                        0
# 740                         0                     1                        1
# 3461                        1                     0                        1
# 5183                        0                     1                        1
# 1188                        1                     1                        0
#
#       Melibiose_fermentation  Citrate  Phenylanine_deaminase  \
# 169                        0        0                      0
# 9354                       0        1                      1
# 3013                       0        1                      0
# 1475                       1        1                      0
# 7420                       1        1                      0
# ...                      ...      ...                    ...
# 1369                       1        1                      0
# 740                        0        0                      1
# 3461                       1        0                      0
# 5183                       0        1                      0
# 1188                       0        1                      0
#
#       Ornithine_decarboxylase  D-Glucose_acid  Lysine_deaminase  \
# 169                         0               1                 0
# 9354                        1               1                 0
# 3013                        0               1                 0
# 1475                        0               1                 0
# 7420                        0               1                 1
# ...                       ...             ...               ...
# 1369                        1               1                 0
# 740                         0               1                 0
# 3461                        1               1                 0
# 5183                        1               1                 0
# 1188                        0               1                 0
#
#       Urea_hydrolysis  Voges-Proskauer  Hydrogen_Sulfide_TSI  \
# 169                 0                0                     1
# 9354                1                0                     1
# 3013                1                0                     1
# 1475                1                0                     0
# 7420                1                1                     0
# ...               ...              ...                   ...
# 1369                0                1                     0
# 740                 0                0                     0
# 3461                1                0                     0
# 5183                1                1                     0
# 1188                0                1                     0
#
#       Sucrose_fermentation  D-Mannose_fermentation  ONPG_test  \
# 169                      0                       0          1
# 9354                     0                       0          0
# 3013                     0                       1          1
# 1475                     1                       1          1
# 7420                     1                       1          1
# ...                    ...                     ...        ...
# 1369                     1                       1          1
# 740                      0                       1          1
# 3461                     1                       1          1
# 5183                     1                       1          1
# 1188                     1                       1          1
#
#       L-Arabinose_fermentation        Target
# 169                          1    B.aquatica
# 9354                         0   P.mirabilis
# 3013                         1   C.warkmanii
# 1475                         1    C.freundii
# 7420                         1  K.plantocila
# ...                        ...           ...
# 1369                         0   C.species_5
# 740                          1    B.noackiae
# 3461                         1   C.Group_137
# 5183                         1  E.hormaechei
# 1188                         0      C.neteri
#
# [2920 rows x 20 columns]

# %%
probability_assignments = []
for probs in y_pred_proba:
    sorted_dict = dict(sorted(zip(model_8_panel.classes_, list(probs)), key=lambda item: item[1], reverse=True))
    probability_assignments.append(sorted_dict)
df_results = pd.DataFrame({
    'true': y_test,
    'predicted': y_pred,
    'probability': probability_assignments
})

# %%
df_results[df_results['true'] != df_results['predicted']]
# Out:
#                            true              predicted  \
# 7420               K.plantocila              K.oxytoca
# 8650   M.morganii_subsp.sibonii  M.morganii_biogroup_1
# 13422                  Y.rohdei           Y.bercovieri
# 14389          Enteric_Group_64             B.gaviniae
# 10626     S.Paratyphi_A_Group_I             C.gillenii
# ...                         ...                    ...
# 718                  B.noackiae       Enteric_Group_59
# 3204             C.amalonaticus             C.sedlakii
# 3488                C.Group_137              C.farmeri
# 750                  B.noackiae       Enteric_Group_59
# 3375                  C.farmeri    C.diversus_C.koseri
#
#                                              probability
# 7420   {'K.ornithinolytica': 0.4873866180017171, 'K.o...
# 8650   {'C.diversus_C.koseri': 0.32095787240513246, '...
# 13422  {'Yersinia_ruckeri': 0.07841675216830658, 'K.r...
# 14389  {'Enteric_Group_64': 0.35627016487812446, 'B.g...
# 10626  {'B.brennerae': 0.1276142238324297, 'S.Paratyp...
# ...                                                  ...
# 718    {'E.cancerogenus': 0.10756657544505184, 'C.spe...
# 3204   {'C.sedlakii': 0.41427152307112275, 'C.amalona...
# 3488   {'P.shigelloides': 0.527743256222928, 'C.Group...
# 750    {'E.cancerogenus': 0.10756657544505184, 'C.spe...
# 3375   {'C.diversus_C.koseri': 0.32095787240513246, '...
#
# [599 rows x 3 columns]

# %%
# Save the model
dump(model_20_panel, 'rf_20_panel_enterobac_100.pkl')
# Load the model (for future use)
rf_model_loaded = load('rf_20_panel_enterobac_100.pkl')

# %%
print(df_results[df_results['true'] != df_results['predicted']].iloc[0])
df_results[df_results['true'] != df_results['predicted']].iloc[0].probability
# Out:
# true                                                K.plantocila
# predicted                                              K.oxytoca
# probability    {'K.ornithinolytica': 0.4873866180017171, 'K.o...
# Name: 7420, dtype: object
# {'K.ornithinolytica': 0.4873866180017171,
#  'K.oxytoca': 0.3782078694710493,
#  'K.plantocila': 0.0890226125573437,
#  'C.murliniae': 0.012298365781017595,
#  'C.amalonaticus': 0.011264063501350619,
#  'C.sedlakii': 0.01092188899681114,
#  'Y.frederiksenii': 0.010898581690710568,
#  'A.dalhousiensis': 0.0,
#  'B.agrestic': 0.0,
#  'B.aquatica': 0.0,
#  'B.brennerae': 0.0,
#  'B.ferragutiae': 0.0,
#  'B.gaviniae': 0.0,
#  'B.izardii': 0.0,
#  'B.noackiae': 0.0,
#  'B.warmboldiae': 0.0,
#  'C.Group_137': 0.0,
#  'C.davisae': 0.0,
#  'C.diversus_C.koseri': 0.0,
#  'C.farmeri': 0.0,
#  'C.freundii': 0.0,
#  'C.gillenii': 0.0,
#  'C.lapagei': 0.0,
#  'C.neteri': 0.0,
#  'C.rodentium': 0.0,
#  'C.species_3': 0.0,
#  'C.species_5': 0.0,
#  'C.warkmanii': 0.0,
#  'C.youngae': 0.0,
#  'E.aerogenes': 0.0,
#  'E.agglomerans_complex': 0.0,
#  'E.aloacae': 0.0,
#  'E.americana': 0.0,
#  'E.amnigenus_biogroup_1': 0.0,
#  'E.amnigenus_biogroup_2': 0.0,
#  'E.asburiae': 0.0,
#  'E.blattae': 0.0,
#  'E.cancerogenus': 0.0,
#  'E.coil_invasive': 0.0,
#  'E.coli': 0.0,
#  'E.dissolvens': 0.0,
#  'E.gergoviae': 0.0,
#  'E.hormaechei': 0.0,
#  'E.hoshinae': 0.0,
#  'E.ictaluri': 0.0,
#  'E.nimipressuralis': 0.0,
#  'E.pyrinus': 0.0,
#  'E.tarda': 0.0,
#  'E.tarda_biogroup_1': 0.0,
#  'E.taylorae_E.cancerogenus': 0.0,
#  'E.vulneris': 0.0,
#  'Enteric_Group_59': 0.0,
#  'Enteric_Group_60': 0.0,
#  'Enteric_Group_63': 0.0,
#  'Enteric_Group_64': 0.0,
#  'Enteric_Group_68': 0.0,
#  'Enteric_Group_69': 0.0,
#  'Esakazakii': 0.0,
#  'Group_VI_strains': 0.0,
#  'H.alvei': 0.0,
#  'H.alvei_biogroup_1': 0.0,
#  'K.ascorbata': 0.0,
#  'K.cryocrescens': 0.0,
#  'K.georgiana': 0.0,
#  'K.intermedia': 0.0,
#  'K.ozaenae': 0.0,
#  'K.pneumoniae': 0.0,
#  'K.rhinoscleromatis': 0.0,
#  'K.terrigena': 0.0,
#  'L.adecarboxylata': 0.0,
#  'L.grimontii': 0.0,
#  'L.richardii': 0.0,
#  'M.morganii_biogroup_1': 0.0,
#  'M.morganii_subsp.morganii': 0.0,
#  'M.morganii_subsp.sibonii': 0.0,
#  'M.wisconsensis': 0.0,
#  'O.proteus_biogroup_2': 0.0,
#  'P.alcalifaciens': 0.0,
#  'P.asymbiotica': 0.0,
#  'P.dispersa': 0.0,
#  'P.fontium': 0.0,
#  'P.heimbachae': 0.0,
#  'P.luminescens': 0.0,
#  'P.mirabilis': 0.0,
#  'P.myxofaciens': 0.0,
#  'P.penneri': 0.0,
#  'P.rettgeri': 0.0,
#  'P.rustigianni': 0.0,
#  'P.shigelloides': 0.0,
#  'P.stuartii': 0.0,
#  'P.vulgeris': 0.0,
#  'R.aquatilis': 0.0,
#  'S.Choleresuis_Group_I': 0.0,
#  'S.Gallinarum_Group_I': 0.0,
#  'S.Group_IIIa_strains': 0.0,
#  'S.Group_IIIb_strains': 0.0,
#  'S.Group_II_strains': 0.0,
#  'S.Group_IV_strains': 0.0,
#  'S.Paratyphi_A_Group_I': 0.0,
#  'S.Typhi_Group_I': 0.0,
#  'S.bongeri_Group_V': 0.0,
#  'S.boydii_serogroup_C': 0.0,
#  'S.dysenteriae_serogroup_A': 0.0,
#  'S.enterica_Group_I': 0.0,
#  'S.entomoohila': 0.0,
#  'S.fergusonii': 0.0,
#  'S.ficaria': 0.0,
#  'S.flexneri_serogroup_B': 0.0,
#  'S.hermannii': 0.0,
#  'S.liquefaciens_complex': 0.0,
#  'S.marcescens': 0.0,
#  'S.marcescens_biogroup_1': 0.0,
#  'S.odorifera_biogroup_1': 0.0,
#  'S.odorifera_biogroup_2': 0.0,
#  'S.plymuthica': 0.0,
#  'S.pullorum_Group_I': 0.0,
#  'S.rubidaea': 0.0,
#  'S.sonni_serogroup_D': 0.0,
#  'Serratia_fonticola': 0.0,
#  'T.guamensis': 0.0,
#  'T.ptyseos': 0.0,
#  'X.nematophilus': 0.0,
#  'Y.aldovae': 0.0,
#  'Y.bercovieri': 0.0,
#  'Y.enterocolitica': 0.0,
#  'Y.intermedia': 0.0,
#  'Y.kristensenii': 0.0,
#  'Y.mollaretii': 0.0,
#  'Y.pestis': 0.0,
#  'Y.pseudotuberculosis': 0.0,
#  'Y.regensvurgei_K.trabulsis': 0.0,
#  'Y.rohdei': 0.0,
#  'Yersinia_ruckeri': 0.0}
