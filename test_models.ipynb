# %% [markdown]
# Bacterial identification model 8 panel

# %%
import pandas as pd
from joblib import load
import pickle
import pandas as pd

# %%
# Load the model
with open('./models/rf_8_panel_enterobac_100.pkl', 'rb') as file:
    model = load(file)

# Load the test set
test_set = pd.read_csv('./test_sets/rf_8_panel_enterobac_100_test_set.csv')
X_test = test_set.drop('Target', axis=1)
y_test = test_set['Target']

# Display the features (column names) and the first row of data
features = X_test.columns
first_example = X_test.iloc[0]

# Predict first 3 examples of the test set
y_pred = model.predict(X_test.iloc[:3])
y_actual = y_test.iloc[:3]

for pred, actual in zip(y_pred, y_actual):
    print(f'Predicted: {pred}, Actual: {actual}')
# Out:
# Predicted: C.gillenii, Actual: B.aquatica
# Predicted: C.warkmanii, Actual: P.mirabilis
# Predicted: C.warkmanii, Actual: C.warkmanii

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, Range: {X_test[col].unique()}')
# Out:
# Urea_hydrolysis: Type: int64, Range: [0 1]
# Lactose_fermentation: Type: int64, Range: [1 0]
# D-Glucose_acid: Type: int64, Range: [1 0]
# Citrate: Type: int64, Range: [0 1]
# Motility: Type: int64, Range: [0 1]
# Indole_production: Type: int64, Range: [0 1]
# Hydrogen_Sulfide_TSI: Type: int64, Range: [1 0]
# D-Glucose_Gas: Type: int64, Range: [1 0]

# %%
all_classes = model.classes_
print("All possible categories:", all_classes)
# Out:
# All possible categories: ['A.dalhousiensis' 'B.agrestic' 'B.aquatica' 'B.brennerae' 'B.ferragutiae'
#  'B.gaviniae' 'B.izardii' 'B.noackiae' 'B.warmboldiae' 'C.Group_137'
#  'C.amalonaticus' 'C.davisae' 'C.diversus_C.koseri' 'C.farmeri'
#  'C.freundii' 'C.gillenii' 'C.lapagei' 'C.murliniae' 'C.neteri'
#  'C.rodentium' 'C.sedlakii' 'C.species_3' 'C.species_5' 'C.warkmanii'
#  'C.youngae' 'E.aerogenes' 'E.agglomerans_complex' 'E.aloacae'
#  'E.americana' 'E.amnigenus_biogroup_1' 'E.amnigenus_biogroup_2'
#  'E.asburiae' 'E.blattae' 'E.cancerogenus' 'E.coil_invasive' 'E.coli'
#  'E.dissolvens' 'E.gergoviae' 'E.hormaechei' 'E.hoshinae' 'E.ictaluri'
#  'E.nimipressuralis' 'E.pyrinus' 'E.tarda' 'E.tarda_biogroup_1'
#  'E.taylorae_E.cancerogenus' 'E.vulneris' 'Enteric_Group_59'
#  'Enteric_Group_60' 'Enteric_Group_63' 'Enteric_Group_64'
#  'Enteric_Group_68' 'Enteric_Group_69' 'Esakazakii' 'Group_VI_strains'
#  'H.alvei' 'H.alvei_biogroup_1' 'K.ascorbata' 'K.cryocrescens'
#  'K.georgiana' 'K.intermedia' 'K.ornithinolytica' 'K.oxytoca' 'K.ozaenae'
#  'K.plantocila' 'K.pneumoniae' 'K.rhinoscleromatis' 'K.terrigena'
#  'L.adecarboxylata' 'L.grimontii' 'L.richardii' 'M.morganii_biogroup_1'
#  'M.morganii_subsp.morganii' 'M.morganii_subsp.sibonii' 'M.wisconsensis'
#  'O.proteus_biogroup_2' 'P.alcalifaciens' 'P.asymbiotica' 'P.dispersa'
#  'P.fontium' 'P.heimbachae' 'P.luminescens' 'P.mirabilis' 'P.myxofaciens'
#  'P.penneri' 'P.rettgeri' 'P.rustigianni' 'P.shigelloides' 'P.stuartii'
#  'P.vulgeris' 'R.aquatilis' 'S.Choleresuis_Group_I' 'S.Gallinarum_Group_I'
#  'S.Group_IIIa_strains' 'S.Group_IIIb_strains' 'S.Group_II_strains'
#  'S.Group_IV_strains' 'S.Paratyphi_A_Group_I' 'S.Typhi_Group_I'
#  'S.bongeri_Group_V' 'S.boydii_serogroup_C' 'S.dysenteriae_serogroup_A'
#  'S.enterica_Group_I' 'S.entomoohila' 'S.fergusonii' 'S.ficaria'
#  'S.flexneri_serogroup_B' 'S.hermannii' 'S.liquefaciens_complex'
#  'S.marcescens' 'S.marcescens_biogroup_1' 'S.odorifera_biogroup_1'
#  'S.odorifera_biogroup_2' 'S.plymuthica' 'S.pullorum_Group_I' 'S.rubidaea'
#  'S.sonni_serogroup_D' 'Serratia_fonticola' 'T.guamensis' 'T.ptyseos'
#  'X.nematophilus' 'Y.aldovae' 'Y.bercovieri' 'Y.enterocolitica'
#  'Y.frederiksenii' 'Y.intermedia' 'Y.kristensenii' 'Y.mollaretii'
#  'Y.pestis' 'Y.pseudotuberculosis' 'Y.regensvurgei_K.trabulsis' 'Y.rohdei'
#  'Yersinia_ruckeri']

# %% [markdown]
# Bacterial identification model 20 panel

# %%
# Load the model and label encoder from the pickle file
with open('./models/rf_20_panel_enterobac_100.pkl', 'rb') as file:
    model = load(file)

test_set = pd.read_csv('./test_sets/rf_20_panel_enterobac_100_test_set.csv')
X_test = test_set.drop('Target', axis=1)
y_test = test_set['Target']

# Predict first 3 examples of the test set
y_pred = model.predict(X_test.iloc[:3])
y_actual = y_test.iloc[:3]

for pred, actual in zip(y_pred, y_actual):
    print(f'Predicted: {pred}, Actual: {actual}')
# Out:
# Predicted: B.aquatica, Actual: B.aquatica
# Predicted: P.mirabilis, Actual: P.mirabilis
# Predicted: C.warkmanii, Actual: C.warkmanii

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, Range: {X_test[col].unique()}')
# Out:
# Indole_production: Type: int64, Range: [0 1]
# myo-Inositol_fermentation: Type: int64, Range: [0 1]
# Gelatin_hydrolysis_22_c: Type: int64, Range: [0 1]
# D-Sorbitol_fermentation: Type: int64, Range: [0 1]
# Arginine_dihydrolase: Type: int64, Range: [0 1]
# L-Rhamnose_fermentation: Type: int64, Range: [1 0]
# Melibiose_fermentation: Type: int64, Range: [0 1]
# Citrate: Type: int64, Range: [0 1]
# Phenylanine_deaminase: Type: int64, Range: [0 1]
# Ornithine_decarboxylase: Type: int64, Range: [0 1]
# D-Glucose_acid: Type: int64, Range: [1 0]
# Lysine_deaminase: Type: int64, Range: [0 1]
# Urea_hydrolysis: Type: int64, Range: [0 1]
# Voges-Proskauer: Type: int64, Range: [0 1]
# Hydrogen_Sulfide_TSI: Type: int64, Range: [1 0]
# Sucrose_fermentation: Type: int64, Range: [0 1]
# D-Mannose_fermentation: Type: int64, Range: [0 1]
# ONPG_test: Type: int64, Range: [1 0]
# L-Arabinose_fermentation: Type: int64, Range: [1 0]

# %% [markdown]
# MIC Interpretation model

# %%
# Load the model and label encoder from the pickle file
with open('./models/mic_i_classification_best.pkl', 'rb') as file:
    model_and_encoder = pickle.load(file)

model = model_and_encoder['model']
label_encoder = model_and_encoder['label_encoder']

# Load the test set
test_set = pd.read_csv('./test_sets/MIC_Interpretation_test_set.csv')

# Ensure categorical columns are properly formatted
categorical_columns = test_set.select_dtypes(include=['object']).columns

# Convert the categorical columns to 'category' dtype
for col in categorical_columns:
    test_set[col] = test_set[col].astype('category')

# Separate the features and target for the entire test set
X_test = test_set.drop(columns=['MIC_Interpretation'])
y_test = test_set['MIC_Interpretation']

# Select the first two test examples
test_example_x = X_test.iloc[[0, 1]]  # Ensure it's a DataFrame
test_example_y = y_test.iloc[[0, 1]]  # Ensure it's a Series

# Predict the test examples
y_pred = model.predict(test_example_x)

# Decode the predicted labels
y_pred_decoded = label_encoder.inverse_transform(y_pred)

# Decode the actual labels
test_example_y_decoded = label_encoder.inverse_transform(test_example_y.values)

for i in range(len(y_pred_decoded)):
    print(f"Predicted: {y_pred_decoded[i]}, Actual: {test_example_y_decoded[i]}")
# Out:
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:34:22] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:363:
#   Loading from a raw memory buffer (like pickle in Python, RDS in R) on a CPU-only
#   machine. Consider using `save_model/load_model` instead. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.  Changing `tree_method` to `hist`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:34:22] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:388: Changing updater from `grow_gpu_hist` to `grow_quantile_histmaker`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:34:22] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Predicted: Resistant, Actual: Resistant
# Predicted: Susceptible, Actual: Susceptible

# %%
test_example_x
# Out:
#   Phenotype                 Species                Family    Country State  \
# 0      MRSA   Staphylococcus aureus    Staphylococcus spp  Australia   NaN
# 1       NaN  Pseudomonas aeruginosa  Non-Enterobacterales     Brazil   NaN
#
#    Gender       Age Group        Speciality            Source  \
# 0    Male     85 and Over  Medicine General            Sputum
# 1  Female  19 to 64 Years      Medicine ICU  Peritoneal Fluid
#
#   In / Out Patient  Year             Antibiotic
# 0        Inpatient  2013           Erythromycin
# 1              NaN  2022  Ceftazidime avibactam

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, {X_test[col].nunique()} unique values')
# Out:
# Phenotype: Type: category, 5 unique values
# Species: Type: category, 361 unique values
# Family: Type: category, 12 unique values
# Country: Type: category, 83 unique values
# State: Type: category, 46 unique values
# Gender: Type: category, 2 unique values
# Age Group: Type: category, 7 unique values
# Speciality: Type: category, 12 unique values
# Source: Type: category, 97 unique values
# In / Out Patient: Type: category, 4 unique values
# Year: Type: int64, 19 unique values
# Antibiotic: Type: category, 42 unique values

# %% [markdown]
# MIC model

# %%
# Load the model and label encoder from the pickle file
with open('./models/mic_classification_best.pkl', 'rb') as file:
    model_and_encoder = pickle.load(file)

model = model_and_encoder['model']
label_encoder = model_and_encoder['label_encoder']

# Load the test set
test_set = pd.read_csv('./test_sets/MIC_test_set.csv')

# Ensure categorical columns are properly formatted
categorical_columns = test_set.select_dtypes(include=['object']).columns

# Convert the categorical columns to 'category' dtype
for col in categorical_columns:
    test_set[col] = test_set[col].astype('category')

# Separate the features and target for the entire test set
X_test = test_set.drop(columns=['MIC'])
y_test = test_set['MIC']

# Select the first test example
test_example_x = X_test.iloc[:5]  # Ensure it's a DataFrame
test_example_y = y_test.iloc[0:5]

# Predict the test example
y_pred = model.predict(test_example_x)

# Decode the predicted label
y_pred_decoded = label_encoder.inverse_transform(y_pred)
# Decode the actual label
test_example_y_decoded = label_encoder.inverse_transform(test_example_y)

print(f"Predicted: {y_pred_decoded}, Actual: {test_example_y_decoded}")
# Out:
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:25:50] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:363:
#   Loading from a raw memory buffer (like pickle in Python, RDS in R) on a CPU-only
#   machine. Consider using `save_model/load_model` instead. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.  Changing `tree_method` to `hist`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:25:50] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:388: Changing updater from `grow_gpu_hist` to `grow_quantile_histmaker`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:25:50] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Predicted: ['>64' '0.12' '>8' '1' '1'], Actual: ['4' '>16' '2' '>4' '4']

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, {X_test[col].nunique()} unique values')
# Out:
# Phenotype: Type: category, 5 unique values
# Species: Type: category, 365 unique values
# Family: Type: category, 15 unique values
# Country: Type: category, 83 unique values
# State: Type: category, 46 unique values
# Gender: Type: category, 2 unique values
# Age Group: Type: category, 7 unique values
# Speciality: Type: category, 12 unique values
# Source: Type: category, 97 unique values
# In / Out Patient: Type: category, 4 unique values
# Year: Type: int64, 19 unique values
# Antibiotic: Type: category, 49 unique values

# %% [markdown]
# Gene binary classification model

# %%
# Load the model and label encoder from the pickle file
with open('./models/gene_bin_classification_best.pkl', 'rb') as file:
    model_and_encoder = pickle.load(file)

model = model_and_encoder['model']
label_encoder = model_and_encoder['label_encoder']

# Load the test set
test_set = pd.read_csv('./test_sets/gene_bin_test_set.csv')

# Ensure categorical columns are properly formatted
categorical_columns = test_set.select_dtypes(include=['object']).columns

# Convert the categorical columns to 'category' dtype
for col in categorical_columns:
    test_set[col] = test_set[col].astype('category')

# Separate the features and target for the entire test set
X_test = test_set.drop(columns=['detected_binary'])
y_test = test_set['detected_binary']

# Initialize a set to keep track of the predicted categories and a dictionary to store inputs
predicted_categories = set()
inputs_for_categories = {}

# Iterate over the test set to find examples that yield different predictions
for i in range(len(X_test)):
    test_example_x = X_test.iloc[[i]]  # Ensure it's a DataFrame
    test_example_y = y_test.iloc[i]

    # Predict the test example
    y_pred = model.predict(test_example_x)

    # Decode the predicted label
    y_pred_decoded = label_encoder.inverse_transform(y_pred)[0]

    # Decode the actual label
    test_example_y_decoded = label_encoder.inverse_transform([test_example_y])[0]

    # Print the prediction, the actual value, and the input data
    print(f"Predicted: {y_pred_decoded}, Actual: {test_example_y_decoded}")
    print(f"Input data:\n{test_example_x}\n")

    # Add the predicted category to the set and store the input data if it's a new category
    if y_pred_decoded not in predicted_categories:
        predicted_categories.add(y_pred_decoded)
        inputs_for_categories[y_pred_decoded] = test_example_x

    # If we've seen all categories, stop the loop
    if len(predicted_categories) == len(label_encoder.classes_):
        break

# Print out the inputs for each unique category
print("\nInputs for each unique predicted category:")
for category, input_data in inputs_for_categories.items():
    print(f"\nCategory: {category}")
    print(input_data)

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, {X_test[col].nunique()} unique values')
# Out:
# Phenotype: Type: category, 1 unique values
# Species: Type: category, 40 unique values
# Family: Type: category, 2 unique values
# Country: Type: category, 70 unique values
# State: Type: category, 36 unique values
# Gender: Type: category, 2 unique values
# Age Group: Type: category, 7 unique values
# Speciality: Type: category, 12 unique values
# Source: Type: category, 80 unique values
# In / Out Patient: Type: category, 3 unique values
# Year: Type: int64, 18 unique values
# gene: Type: category, 23 unique values

# %% [markdown]
# Gene mult classification model

# %%
# Load the model and label encoder from the pickle file
with open('./models/gene_mult_classification_best.pkl', 'rb') as file:
    model_and_encoder = pickle.load(file)

model = model_and_encoder['model']
label_encoder = model_and_encoder['label_encoder']

# Load the test set
test_set = pd.read_csv('./test_sets/gene_mult_test_set.csv')

# Ensure categorical columns are properly formatted
categorical_columns = test_set.select_dtypes(include=['object']).columns

# Convert the categorical columns to 'category' dtype
for col in categorical_columns:
    test_set[col] = test_set[col].astype('category')

# Separate the features and target for the entire test set
X_test = test_set.drop(columns=['detected_variant'])
y_test = test_set['detected_variant']

# Randomly select 4 test examples
test_example_x = X_test.iloc[[0,1,2,3]]  # Ensure it's a DataFrame
test_example_y = y_test.iloc[[0,1,2,3]]

# Predict the test example
y_pred = model.predict(test_example_x)

# Decode the predicted label
y_pred_decoded = label_encoder.inverse_transform(y_pred)
# Decode the actual label
test_example_y_decoded = label_encoder.inverse_transform(test_example_y)

for i in range(len(y_pred_decoded)):
    print(f"Predicted: {y_pred_decoded[i]}, Actual: {test_example_y_decoded[i]}")
# Out:
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:34:15] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:363:
#   Loading from a raw memory buffer (like pickle in Python, RDS in R) on a CPU-only
#   machine. Consider using `save_model/load_model` instead. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.  Changing `tree_method` to `hist`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:34:15] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/gbtree.cc:388: Changing updater from `grow_gpu_hist` to `grow_quantile_histmaker`.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:34:15] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# /Users/thomaslim/miniconda3/envs/microbis/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No example found for category '0' in the test set.
# No example found for category 'ACC-1' in the test set.
# No example found for category 'ACC-4' in the test set.
# No example found for category 'ACT' in the test set.
# No example found for category 'ACT-TYPE' in the test set.
# No example found for category 'CMY' in the test set.
# No example found for category 'CMY-13' in the test set.
# No example found for category 'CMY-145' in the test set.
# No example found for category 'CMY-16' in the test set.
# No example found for category 'CMY-2' in the test set.
# No example found for category 'CMY-2-TYPE' in the test set.
# No example found for category 'CMY-4' in the test set.
# No example found for category 'CMY-42' in the test set.
# No example found for category 'CMY-6' in the test set.
# No example found for category 'CMY-TYPE' in the test set.
# No example found for category 'CTX-M-1' in the test set.
# No example found for category 'CTX-M-1-TYPE' in the test set.
# No example found for category 'CTX-M-12' in the test set.
# No example found for category 'CTX-M-136' in the test set.
# No example found for category 'CTX-M-14' in the test set.
# No example found for category 'CTX-M-15' in the test set.
# No example found for category 'CTX-M-15-3' in the test set.
# No example found for category 'CTX-M-2' in the test set.
# No example found for category 'CTX-M-2-TYPE' in the test set.
# No example found for category 'CTX-M-24' in the test set.
# No example found for category 'CTX-M-27' in the test set.
# No example found for category 'CTX-M-28' in the test set.
# No example found for category 'CTX-M-3' in the test set.
# No example found for category 'CTX-M-30' in the test set.
# No example found for category 'CTX-M-32' in the test set.
# No example found for category 'CTX-M-55' in the test set.
# No example found for category 'CTX-M-65' in the test set.
# No example found for category 'CTX-M-79' in the test set.
# No example found for category 'CTX-M-8' in the test set.
# No example found for category 'CTX-M-9' in the test set.
# No example found for category 'CTX-M-9-TYPE' in the test set.
# No example found for category 'CTX-M-TYPE' in the test set.
# No example found for category 'DHA' in the test set.
# No example found for category 'DHA-1' in the test set.
# No example found for category 'DHA-TRUNC' in the test set.
# No example found for category 'DHA-TYPE' in the test set.
# No example found for category 'FOX' in the test set.
# No example found for category 'GES' in the test set.
# No example found for category 'GES-1' in the test set.
# No example found for category 'GES-1(e)' in the test set.
# No example found for category 'GES-11' in the test set.
# No example found for category 'GES-19-20' in the test set.
# No example found for category 'GES-2' in the test set.
# No example found for category 'GES-20' in the test set.
# No example found for category 'GES-20(c)' in the test set.
# No example found for category 'GES-5' in the test set.
# No example found for category 'GES-5(c)' in the test set.
# No example found for category 'GES-6' in the test set.
# No example found for category 'GES-TYPE(u)' in the test set.
# No example found for category 'IMP-1' in the test set.
# No example found for category 'IMP-13' in the test set.
# No example found for category 'IMP-14' in the test set.
# No example found for category 'IMP-15' in the test set.
# No example found for category 'IMP-18' in the test set.
# No example found for category 'IMP-26' in the test set.
# No example found for category 'IMP-4' in the test set.
# No example found for category 'IMP-48' in the test set.
# No example found for category 'IMP-6' in the test set.
# No example found for category 'IMP-7' in the test set.
# No example found for category 'IMP-8' in the test set.
# No example found for category 'KPC' in the test set.
# No example found for category 'KPC-2' in the test set.
# No example found for category 'KPC-3' in the test set.
# No example found for category 'KPC-TYPE' in the test set.
# No example found for category 'MIR-TYPE' in the test set.
# No example found for category 'NDM-1' in the test set.
# No example found for category 'NDM-5' in the test set.
# No example found for category 'NDM-6' in the test set.
# No example found for category 'NDM-7' in the test set.
# No example found for category 'NDM-TYPE' in the test set.
# No example found for category 'NEG' in the test set.
# No example found for category 'OXA-163' in the test set.
# No example found for category 'OXA-181' in the test set.
# No example found for category 'OXA-181(c)' in the test set.
# No example found for category 'OXA-23' in the test set.
# No example found for category 'OXA-232' in the test set.
# No example found for category 'OXA-232(c)' in the test set.
# No example found for category 'OXA-239' in the test set.
# No example found for category 'OXA-24' in the test set.
# No example found for category 'OXA-244' in the test set.
# No example found for category 'OXA-370' in the test set.
# No example found for category 'OXA-48' in the test set.
# No example found for category 'OXA-48(c)' in the test set.
# No example found for category 'OXA-48-New Variant' in the test set.
# No example found for category 'OXA-58' in the test set.
# No example found for category 'OXA-72' in the test set.
# No example found for category 'PER-1' in the test set.
# No example found for category 'PER-3' in the test set.
# No example found for category 'POS' in the test set.
# No example found for category 'SHV-1' in the test set.
# No example found for category 'SHV-1(b)' in the test set.
# No example found for category 'SHV-11' in the test set.
# No example found for category 'SHV-11(b)' in the test set.
# No example found for category 'SHV-110' in the test set.
# No example found for category 'SHV-12' in the test set.
# No example found for category 'SHV-12(e)' in the test set.
# No example found for category 'SHV-168' in the test set.
# No example found for category 'SHV-2' in the test set.
# No example found for category 'SHV-2(e)' in the test set.
# No example found for category 'SHV-27' in the test set.
# No example found for category 'SHV-27(b)' in the test set.
# No example found for category 'SHV-28' in the test set.
# No example found for category 'SHV-28(e)' in the test set.
# No example found for category 'SHV-2A' in the test set.
# No example found for category 'SHV-2A(e)' in the test set.
# No example found for category 'SHV-31' in the test set.
# No example found for category 'SHV-31(e)' in the test set.
# No example found for category 'SHV-32' in the test set.
# No example found for category 'SHV-38' in the test set.
# No example found for category 'SHV-5' in the test set.
# No example found for category 'SHV-5(e)' in the test set.
# No example found for category 'SHV-7' in the test set.
# No example found for category 'SHV-7(e)' in the test set.
# No example found for category 'SHV-76' in the test set.
# No example found for category 'SHV-83' in the test set.
# No example found for category 'SHV-ESBL' in the test set.
# No example found for category 'SHV-ESBL(e)' in the test set.
# No example found for category 'SHV-OSBL' in the test set.
# No example found for category 'SHV-OSBL(b)' in the test set.
# No example found for category 'SHV-TYPE' in the test set.
# No example found for category 'TEM-1' in the test set.
# No example found for category 'TEM-1(b)' in the test set.
# No example found for category 'TEM-12' in the test set.
# No example found for category 'TEM-24' in the test set.
# No example found for category 'TEM-24(e)' in the test set.
# No example found for category 'TEM-52' in the test set.
# No example found for category 'TEM-52(e)' in the test set.
# No example found for category 'TEM-92' in the test set.
# No example found for category 'TEM-ESBL' in the test set.
# No example found for category 'TEM-OSBL' in the test set.
# No example found for category 'TEM-OSBL(b)' in the test set.
# No example found for category 'VEB-1' in the test set.
# No example found for category 'VEB-14' in the test set.
# No example found for category 'VEB-1A' in the test set.
# No example found for category 'VEB-1B' in the test set.
# No example found for category 'VEB-5' in the test set.
# No example found for category 'VEB-6' in the test set.
# No example found for category 'VEB-9' in the test set.
# No example found for category 'VIM' in the test set.
# No example found for category 'VIM-1' in the test set.
# No example found for category 'VIM-2' in the test set.
# No example found for category 'VIM-23' in the test set.
# No example found for category 'VIM-24' in the test set.
# No example found for category 'VIM-26' in the test set.
# No example found for category 'VIM-4' in the test set.
# No example found for category 'VIM-5' in the test set.

# %%
# Get the type and unique values for each column
for col in X_test.columns:
    print(f'{col}: Type: {X_test[col].dtype}, {X_test[col].nunique()} unique values')
# Out:
# Phenotype: Type: category, 1 unique values
# Species: Type: category, 40 unique values
# Family: Type: category, 2 unique values
# Country: Type: category, 70 unique values
# State: Type: category, 36 unique values
# Gender: Type: category, 2 unique values
# Age Group: Type: category, 7 unique values
# Speciality: Type: category, 12 unique values
# Source: Type: category, 80 unique values
# In / Out Patient: Type: category, 3 unique values
# Year: Type: int64, 18 unique values
# gene: Type: category, 23 unique values

# %%
test_example_x
# Out:
#        Phenotype                 Species                  Family  \
# 44658       ESBL        Escherichia coli      Enterobacteriaceae
# 114043      ESBL        Escherichia coli      Enterobacteriaceae
# 110760      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 199397       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 315253      ESBL        Escherichia coli      Enterobacteriaceae
# 166811      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 182423      ESBL        Escherichia coli      Enterobacteriaceae
# 259895       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 272484      ESBL        Escherichia coli      Enterobacteriaceae
# 23669        NaN   Klebsiella pneumoniae      Enterobacteriaceae
# 120782      ESBL        Escherichia coli      Enterobacteriaceae
# 198707      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 114095       NaN      Klebsiella oxytoca      Enterobacteriaceae
# 274643      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 316781      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 17096       ESBL        Escherichia coli      Enterobacteriaceae
# 258155       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 149411      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 82973        NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 103639      ESBL        Escherichia coli      Enterobacteriaceae
# 284315       NaN   Klebsiella pneumoniae      Enterobacteriaceae
# 190566      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 246099      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 235595      ESBL        Escherichia coli      Enterobacteriaceae
# 113751       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 154709      ESBL        Escherichia coli      Enterobacteriaceae
# 153400       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 247974       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 57599       ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 779         ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 7061        ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 228047      ESBL        Escherichia coli      Enterobacteriaceae
# 89708       ESBL        Escherichia coli      Enterobacteriaceae
# 174860      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 68707       ESBL        Escherichia coli      Enterobacteriaceae
# 27274       ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 24547       ESBL        Escherichia coli      Enterobacteriaceae
# 230965       NaN  Pseudomonas aeruginosa  Non-Enterobacteriaceae
# 154493      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
# 235803      ESBL   Klebsiella pneumoniae      Enterobacteriaceae
#
#                Country       State  Gender       Age Group  \
# 44658         Thailand         NaN  Female  65 to 84 Years
# 114043          Kuwait         NaN  Female  19 to 64 Years
# 110760    South Africa         NaN    Male         Unknown
# 199397          Russia         NaN    Male  65 to 84 Years
# 315253          Mexico         NaN    Male  19 to 64 Years
# 166811        Portugal         NaN    Male  65 to 84 Years
# 182423         Hungary         NaN    Male  65 to 84 Years
# 259895           Spain         NaN    Male  19 to 64 Years
# 272484    Korea, South         NaN  Female  65 to 84 Years
# 23669            Italy         NaN  Female  19 to 64 Years
# 120782   United States    New York  Female  65 to 84 Years
# 198707          Russia         NaN  Female  65 to 84 Years
# 114095        Thailand         NaN    Male  19 to 64 Years
# 274643          Poland         NaN    Male   3 to 12 Years
# 316781          Israel         NaN    Male  65 to 84 Years
# 17096     South Africa         NaN  Female  19 to 64 Years
# 258155  Czech Republic         NaN    Male  19 to 64 Years
# 149411          Russia         NaN    Male    0 to 2 Years
# 82973           Kuwait         NaN    Male  19 to 64 Years
# 103639          Israel         NaN  Female     85 and Over
# 284315         Ukraine         NaN  Female    0 to 2 Years
# 190566          Russia         NaN  Female  65 to 84 Years
# 246099           Italy         NaN    Male     85 and Over
# 235595  United Kingdom         NaN  Female  65 to 84 Years
# 113751          Turkey         NaN    Male   3 to 12 Years
# 154709       Guatemala         NaN  Female  19 to 64 Years
# 153400        Portugal         NaN  Female  65 to 84 Years
# 247974         Hungary         NaN    Male  19 to 64 Years
# 57599           Kuwait         NaN  Female  19 to 64 Years
# 779      United States  New Jersey  Female  65 to 84 Years
# 7061      Korea, South         NaN    Male  65 to 84 Years
# 228047       Australia         NaN    Male  65 to 84 Years
# 89708            China         NaN     NaN  19 to 64 Years
# 174860          Russia         NaN    Male  19 to 64 Years
# 68707    United States        Ohio  Female  65 to 84 Years
# 27274           Panama         NaN  Female  19 to 64 Years
# 24547            Italy         NaN    Male  19 to 64 Years
# 230965          Poland         NaN    Male  13 to 18 Years
# 154493           India         NaN    Male     85 and Over
# 235803        Colombia         NaN    Male  65 to 84 Years
#
#                      Speciality                  Source In / Out Patient  \
# 44658               Surgery ICU        Peritoneal Fluid              NaN
# 114043         Medicine General             Skin: Other        Inpatient
# 110760         Medicine General                  Sputum       None Given
# 199397          Surgery General                   Wound        Inpatient
# 315253             Medicine ICU   Endotracheal aspirate              NaN
# 166811             Medicine ICU                  Sputum        Inpatient
# 182423         Medicine General                  Sputum        Inpatient
# 259895             Medicine ICU      Respiratory: Other              NaN
# 272484         Medicine General                   Urine        Inpatient
# 23669              Medicine ICU   Endotracheal aspirate              NaN
# 120782         Medicine General                   Blood              NaN
# 198707         Medicine General  Bronchoalveolar lavage              NaN
# 114095         Medicine General                  Sputum              NaN
# 274643               None Given                   Blood              NaN
# 316781         Medicine General                   Wound        Inpatient
# 17096   General Unspecified ICU                  Sputum              NaN
# 258155             Medicine ICU                  Sputum              NaN
# 149411        Pediatric General                   Urine              NaN
# 82973           Surgery General                   Wound              NaN
# 103639          Surgery General            Gall Bladder        Inpatient
# 284315            Pediatric ICU  Bronchoalveolar lavage              NaN
# 190566              Surgery ICU     Thoracentesis Fluid              NaN
# 246099         Medicine General                   Blood        Inpatient
# 235595             Medicine ICU                  Sputum              NaN
# 113751            Pediatric ICU                   Blood              NaN
# 154709               None Given        Peritoneal Fluid       None Given
# 153400              Surgery ICU   Endotracheal aspirate        Inpatient
# 247974              Surgery ICU                   Blood              NaN
# 57599          Medicine General                   Urine        Inpatient
# 779                  None Given             Lymph Nodes       None Given
# 7061           Medicine General                   Urine        Inpatient
# 228047         Medicine General        Peritoneal Fluid              NaN
# 89708          Medicine General                   Urine        Inpatient
# 174860          Surgery General                   Wound        Inpatient
# 68707                None Given                  Sputum       None Given
# 27274              Medicine ICU               Catheters        Inpatient
# 24547          Medicine General  Bronchoalveolar lavage              NaN
# 230965                    Other  Bronchoalveolar lavage              NaN
# 154493              Surgery ICU                   Blood       None Given
# 235803             Medicine ICU                  Sputum        Inpatient
#
#         Year     gene
# 44658   2018  CMY1MOX
# 114043  2016    CTXM1
# 110760  2020      IMP
# 199397  2012      KPC
# 315253  2021      IMP
# 166811  2012      TEM
# 182423  2016      ACC
# 259895  2019      SHV
# 272484  2016      VIM
# 23669   2017      FOX
# 120782  2019      OXA
# 198707  2017      SHV
# 114095  2017      KPC
# 274643  2019     AMPC
# 316781  2016      PER
# 17096   2019      OXA
# 258155  2019      VEB
# 149411  2019      ACC
# 82973   2019      GIM
# 103639  2013      ACC
# 284315  2018    CMY11
# 190566  2019      PER
# 246099  2014      SHV
# 235595  2017      PER
# 113751  2019      DHA
# 154709  2015    CTXM9
# 153400  2014      KPC
# 247974  2019      KPC
# 57599   2015      VEB
# 779     2009      TEM
# 7061    2012      DHA
# 228047  2018      KPC
# 89708   2012      FOX
# 174860  2014      TEM
# 68707   2014      GES
# 27274   2006    CMY11
# 24547   2019    CTXM9
# 230965  2019      NDM
# 154493  2020    CTXM2
# 235803  2015      SHV

# %%
# randomly select 10 examples from the test set and predict
test_example_x = X_test.sample(40)
test_example_y = y_test.loc[test_example_x.index]

# Predict the test examples

y_pred = model.predict(test_example_x)

# Decode the predicted labels

y_pred_decoded = label_encoder.inverse_transform(y_pred)

# Decode the actual labels

test_example_y_decoded = label_encoder.inverse_transform(test_example_y)

for i in range(len(y_pred_decoded)):
    print(f"Predicted: {y_pred_decoded[i]}, Actual: {test_example_y_decoded[i]}")
# Out:
# Predicted: NEG, Actual: NEG
# Predicted: CTX-M-15, Actual: CTX-M-15
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: TEM-1, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: SHV-OSBL, Actual: SHV-OSBL
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: SHV-OSBL(b), Actual: SHV-OSBL(b)
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: TEM-OSBL(b), Actual: TEM-OSBL(b)
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: TEM-OSBL, Actual: TEM-OSBL
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: NEG, Actual: NEG
# Predicted: SHV-OSBL, Actual: SHV-OSBL

# %%
label_encoder.inverse_transform(model.predict(test_example_x.loc[[109620]]))
# Out:
# array(['CTX-M-15'], dtype=object)
